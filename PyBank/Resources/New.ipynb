# %%
#access and import CSV

import os
import csv

# Specify the correct file path based on the given directory structure
desktop_path = os.path.expanduser("~/Desktop")
module_path = os.path.join(desktop_path, "module-03-starter-code")
pybank_path = os.path.join(module_path, "pybank")
pybank_csv = os.path.join(pybank_path, "Resources", "budget_data.csv")

# Open and read the CSV file

with open(pybank_csv, 'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",")
        
    total_months = 0
    total_profit = 0
    greatest_profit = -9999999
    first_row = True
    total_change = 0
    
    next(csv_reader)
    for row in csv_reader:
        #skip the header
   #     if not row[0].startswith("Date"):
        total_months +=1
        current_profit =int(row[1])
        total_profit += current_profit
        
        #to do: skip change for 1st rows
        if first_row:
            first_row = False
        else: 
            current_change =current_profit - prev_profit 
            print("current_change", current_change)
        #prepare for next row
        prev_profit= current_profit

            
# print ("Financial Analysis")
# print ('----------------------------')
print (f"Total Months: {total_months}")
print (f"Total: ${total_profit}")
#print (f"Average Change: {average_change}")
#print (f"Greatest Increase in Profits: {row[0]}{greatest_profit}")
#print (f" Greatest Decrease in Profits: {row[0]} {lowest_profit}")
# Out:
# current_change -1443517
# current_change 631156
# current_change -1004755
# current_change 1581126
# current_change -289272
# current_change -1098929
# current_change 1167557
# current_change -806093
# current_change 1124485
# current_change -1736491
# current_change -408383
# current_change 604557
# current_change -294345
# current_change 1327485
# current_change 394323
# current_change 243585
# current_change -617439
# current_change -1530577
# current_change 1390390
# current_change -1130397
# current_change 1293604
# current_change 641758
# current_change -337413
# current_change -52031
# current_change -937192
# current_change 863841
# current_change -76245
# current_change -100481
# current_change -960729
# current_change 591856
# current_change 54930
# current_change 680102
# current_change -250254
# current_change -840415
# current_change 582358
# current_change -48628
# current_change -135256
# current_change 978586
# current_change -599210
# current_change -442789
# current_change 652924
# current_change -1005714
# current_change 1167373
# current_change -234900
# current_change -165147
# current_change -52275
# current_change -302320
# current_change 719028
# current_change -1825558
# current_change 1287083
# current_change -48303
# current_change 210234
# current_change -236414
# current_change 585165
# current_change -1400632
# current_change 839777
# current_change 465229
# current_change 317811
# current_change -760202
# current_change -71868
# current_change 795457
# current_change -182685
# current_change -1242836
# current_change 1371884
# current_change -445193
# current_change 10025
# current_change -1043998
# current_change 1350395
# current_change 80538
# current_change -1223250
# current_change 104148
# current_change 843924
# current_change -1808664
# current_change 1505005
# current_change 306402
# current_change -143603
# current_change -1266937
# current_change -162519
# current_change 1862002
# current_change -52986
# current_change -1627245
# current_change 616795
# current_change 628522
# current_change 90895
# current_change -224669
# Total Months: 86
# Total: $22564198
